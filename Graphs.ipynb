# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

import os

# %%
print(matplotlib.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.7.2
# 2.0.3
# 1.24.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

file = 'naCL_graph.xlsx'

# Read the Excel file
data = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 1')
data1 = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 2')

# Extract wavelength values
# Extract wavelength values
wavelengths = data['wavelength(um)']
wavelengths1 = data1['wl1.39']

# Extract data for different na values
na_131 = data['na=1.31']
na_132 = data['na=1.32']
na_133 = data['na=1.33']
na_134 = data['na=1.34']
na_135 = data['na=1.35']
na_136 = data['na=1.36']
na_137 = data['na=1.37']
na_138 = data['na=1.38']

na_139 = data1['na=1.39']
na_140 = data1['na=1.40']
na_141 = data1['na=1.41']

wavelengths_new = np.linspace(wavelengths.min(), wavelengths.max(), 300)
wavelengths_new1 = np.linspace(wavelengths1.min(), wavelengths1.max(), 300)

na_131_smooth = make_interp_spline(wavelengths, na_131)(wavelengths_new)
na_132_smooth = make_interp_spline(wavelengths, na_132)(wavelengths_new)
na_133_smooth = make_interp_spline(wavelengths, na_133)(wavelengths_new)
na_134_smooth = make_interp_spline(wavelengths, na_134)(wavelengths_new)
na_135_smooth = make_interp_spline(wavelengths, na_135)(wavelengths_new)
na_136_smooth = make_interp_spline(wavelengths, na_136)(wavelengths_new)
na_137_smooth = make_interp_spline(wavelengths, na_137)(wavelengths_new)
na_138_smooth = make_interp_spline(wavelengths, na_138)(wavelengths_new)

na_139_smooth = make_interp_spline(wavelengths1, na_139)(wavelengths_new1)
na_140_smooth = make_interp_spline(wavelengths1, na_140)(wavelengths_new1)
na_141_smooth = make_interp_spline(wavelengths1, na_141)(wavelengths_new1)

plt.figure(figsize=(6, 5))
# Plot the data with smoother lines and different colors
plt.plot(wavelengths_new, na_131_smooth, color='b', label='na=1.31')
plt.plot(wavelengths_new, na_132_smooth, color='g', label='na=1.32')
plt.plot(wavelengths_new, na_133_smooth, color='r', label='na=1.33')
plt.plot(wavelengths_new, na_134_smooth, color='c', label='na=1.34')
plt.plot(wavelengths_new, na_135_smooth, color='m', label='na=1.35')
plt.plot(wavelengths_new, na_136_smooth, color='y', label='na=1.36')
plt.plot(wavelengths_new, na_137_smooth, color='k', label='na=1.37')
plt.plot(wavelengths_new, na_138_smooth, color='orange', label='na=1.38')

# Plot the data with smoother lines and different colors
plt.plot(wavelengths_new1, na_139_smooth, color='b', label='na=1.39')
plt.plot(wavelengths_new1, na_140_smooth, color='g', label='na=1.40')
plt.plot(wavelengths_new1, na_141_smooth, color='r', label='na=1.41')

# Add labels and legend
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('Wavelength (µm)', fontsize='13')
plt.ylabel('Confinement Loss (dB/cm)', fontsize='13')
#plt.title('Confinement Loss vs Wavelength for Different na Values')
plt.legend(fontsize='12')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

file = 'naCL_graph.xlsx'

# Read the Excel file
data = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 1')
data1 = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 2')
data2 = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 1.42')
# Extract wavelength values
# Extract wavelength values
wavelengths = data['wavelength(um)']
wavelengths1 = data1['wl1.39']
wavelengths2 = data2['wl1.42']

# Extract data for different na values
na_131 = data['na=1.31']
na_132 = data['na=1.32']
na_133 = data['na=1.33']
na_134 = data['na=1.34']
na_135 = data['na=1.35']
na_136 = data['na=1.36']
na_137 = data['na=1.37']
na_138 = data['na=1.38']

na_139 = data1['na=1.39']
na_140 = data1['na=1.40']
na_141 = data1['na=1.41']

na_142 = data2['na=1.42']

wavelengths_new = np.linspace(wavelengths.min(), wavelengths.max(), 300)
wavelengths_new1 = np.linspace(wavelengths1.min(), wavelengths1.max(), 300)
wavelengths_new2 = np.linspace(wavelengths1.min(), wavelengths2.max(), 300)

na_131_smooth = make_interp_spline(wavelengths, na_131)(wavelengths_new)
na_132_smooth = make_interp_spline(wavelengths, na_132)(wavelengths_new)
na_133_smooth = make_interp_spline(wavelengths, na_133)(wavelengths_new)
na_134_smooth = make_interp_spline(wavelengths, na_134)(wavelengths_new)
na_135_smooth = make_interp_spline(wavelengths, na_135)(wavelengths_new)
na_136_smooth = make_interp_spline(wavelengths, na_136)(wavelengths_new)
na_137_smooth = make_interp_spline(wavelengths, na_137)(wavelengths_new)
na_138_smooth = make_interp_spline(wavelengths, na_138)(wavelengths_new)

na_142_smooth = make_interp_spline(wavelengths2, na_142)(wavelengths_new2)


plt.figure(figsize=(7, 5))
# Plot the data with smoother lines and different colors
plt.plot(wavelengths_new, na_131_smooth, color='b', label='na=1.31')
plt.plot(wavelengths_new, na_132_smooth, color='g', label='na=1.32')
plt.plot(wavelengths_new, na_133_smooth, color='r', label='na=1.33')
plt.plot(wavelengths_new, na_134_smooth, color='c', label='na=1.34')
plt.plot(wavelengths_new, na_135_smooth, color='m', label='na=1.35')
plt.plot(wavelengths_new, na_136_smooth, color='y', label='na=1.36')
plt.plot(wavelengths_new, na_137_smooth, color='k', label='na=1.37')
plt.plot(wavelengths_new, na_138_smooth, color='orange', label='na=1.38')

# Plot the data with smoother lines and different colors
plt.plot(wavelengths_new1, na_139_smooth, color='b', label='na=1.39')
plt.plot(wavelengths_new1, na_140_smooth, color='g', label='na=1.40')
plt.plot(wavelengths_new1, na_141_smooth, color='r', label='na=1.41')
plt.plot(wavelengths_new2, na_142_smooth, color='c', label='na=1.42')


# Add labels and legend
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('Wavelength (µm)', fontsize='13')
plt.ylabel('Confinement Loss (dB/cm)', fontsize='13')
#plt.title('Confinement Loss vs Wavelength for Different na Values')
plt.legend(loc='upper left', fontsize='11')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

file = 'naCL_graph.xlsx'
# Read the Excel file
data = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 1')

# Extract wavelength values
wavelengths = data['wavelength(um)']

# Extract data for different na ranges
na_131_132 = data['na=1.31-1.32']
na_132_133 = data['na=1.32-1.33']
na_133_134 = data['na=1.33-1.34']
na_134_135 = data['na=1.34-1.35']
na_135_136 = data['na=1.35-1.36']
na_136_137 = data['na=1.36-1.37']
na_137_138 = data['na=1.37-1.38']


# Create a function to smooth the data
def smooth(x, y, num_points=300):
    x_new = np.linspace(x.min(), x.max(), num_points)
    spl = make_interp_spline(x, y, k=3)  # Cubic spline interpolation
    y_smooth = spl(x_new)
    return x_new, y_smooth

# Plot the data with smoother lines
plt.figure(figsize=(10, 6))  # Adjust figure size if needed

x_smooth, y_smooth = smooth(wavelengths, na_131_132)
plt.plot(x_smooth, y_smooth, color='b', label='na=1.31-1.32')

x_smooth, y_smooth = smooth(wavelengths, na_132_133)
plt.plot(x_smooth, y_smooth, color='g', label='na=1.32-1.33')

x_smooth, y_smooth = smooth(wavelengths, na_133_134)
plt.plot(x_smooth, y_smooth, color='r', label='na=1.33-1.34')

x_smooth, y_smooth = smooth(wavelengths, na_134_135)
plt.plot(x_smooth, y_smooth, color='c', label='na=1.34-1.35')

x_smooth, y_smooth = smooth(wavelengths, na_135_136)
plt.plot(x_smooth, y_smooth, color='m', label='na=1.35-1.36')

x_smooth, y_smooth = smooth(wavelengths, na_136_137)
plt.plot(x_smooth, y_smooth, color='y', label='na=1.36-1.37')

x_smooth, y_smooth = smooth(wavelengths, na_137_138)
plt.plot(x_smooth, y_smooth, color='k', label='na=1.37-1.38')


# Add labels and legend
plt.xlabel('Wavelength (µm)')
plt.ylabel('Amplitude Sensitivity (RIU$^{-1}$)')
#plt.title('Amplitude Sensitivity vs Wavelength')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# Plot the data with smoother lines
plt.figure(figsize=(8, 6))  

# Adjust figure size if needed
file = 'naCL_graph.xlsx'
# Read the Excel file
data = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 1')

# Extract wavelength values
wavelengths = data['wavelength(um)']

# Extract data for different na ranges
na_131_132 = data['na=1.31-1.32']
na_132_133 = data['na=1.32-1.33']
na_133_134 = data['na=1.33-1.34']
na_134_135 = data['na=1.34-1.35']
na_135_136 = data['na=1.35-1.36']
na_136_137 = data['na=1.36-1.37']
na_137_138 = data['na=1.37-1.38']


# Create a function to smooth the data
def smooth(x, y, num_points=300):
    x_new = np.linspace(x.min(), x.max(), num_points)
    spl = make_interp_spline(x, y, k=3)  # Cubic spline interpolation
    y_smooth = spl(x_new)
    return x_new, y_smooth

x_smooth, y_smooth = smooth(wavelengths, na_131_132)
plt.plot(x_smooth, y_smooth, color='b', label='na=1.31-1.32')

x_smooth, y_smooth = smooth(wavelengths, na_132_133)
plt.plot(x_smooth, y_smooth, color='g', label='na=1.32-1.33')

x_smooth, y_smooth = smooth(wavelengths, na_133_134)
plt.plot(x_smooth, y_smooth, color='r', label='na=1.33-1.34')

x_smooth, y_smooth = smooth(wavelengths, na_134_135)
plt.plot(x_smooth, y_smooth, color='c', label='na=1.34-1.35')

x_smooth, y_smooth = smooth(wavelengths, na_135_136)
plt.plot(x_smooth, y_smooth, color='m', label='na=1.35-1.36')

x_smooth, y_smooth = smooth(wavelengths, na_136_137)
plt.plot(x_smooth, y_smooth, color='y', label='na=1.36-1.37')

x_smooth, y_smooth = smooth(wavelengths, na_137_138)
plt.plot(x_smooth, y_smooth, color='k', label='na=1.37-1.38')

# Read the Excel file
data1 = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 2')

# Extract wavelength values
wavelengths1 = data1['wl1.39']

# Extract data for different na ranges

na_138_139 = data1['na=1.38-1.39']
na_139_140 = data1['na=1.39-1.40']
na_140_141 = data1['na=1.40-1.41']

# Read the Excel file
data2 = pd.read_excel(file, sheet_name='tg=60nm d1 0.6 d2 1um 1.42 AS')

# Extract wavelength values
wavelengths2 = data2['wl142']
na_141_142 = data2['na=1.41-1.42']

x_smooth, y_smooth = smooth(wavelengths1, na_138_139)
plt.plot(x_smooth, y_smooth, color='b', label='na=1.38-1.39')

x_smooth, y_smooth = smooth(wavelengths1, na_139_140)
plt.plot(x_smooth, y_smooth, color='g', label='na=1.39-1.40')

x_smooth, y_smooth = smooth(wavelengths1, na_140_141)
plt.plot(x_smooth, y_smooth, color='r', label='na=1.40-1.41')

#x_smooth, y_smooth = smooth(wavelengths2, na_141_142)
#plt.plot(x_smooth, y_smooth, color='y', label='na=1.41-1.42')


# Add labels and legend
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('Wavelength (µm)', fontsize='13')
plt.ylabel('Amplitude Sensitivity (RIU$^{-1}$)', fontsize='13')
#plt.title('Amplitude Sensitivity vs Wavelength')
plt.legend(fontsize='13')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Tg 40 nm NA variation d1=0.6,d2=1um

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# Create the DataFrame from the provided data
data = pd.DataFrame({
    'wl(um)': [0.6, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8],
    'tg=30nm': [26.2427255, 39.64401349, 52.99322777, 80.32148379, 137.5858179, 247.975459, 378.8117008, 179.1047259, 103.4330806, 67.9021668, 48.8698858, 37.65274283, 30.54755641, 25.79327847, 22.47631535, 20.08780468, 18.3272023, 17.00812577, 16.01015628, 15.25274254, 14.68038699],
    'tg=40nm': [5.029437555, 5.840212227, 7.05360051, 8.822443188, 11.77943329, 17.11725818, 27.0451083, 40.00443298, 55.93693744, 89.54671506, 158.1186416, 303.5754686, 204.4125326, 115.6748752, 74.18533636, 52.54953502, 40.11281763, 32.39297255, 27.3100763, 23.81012876, 21.31781483],
    'tg=50nm': [2.865061654, 3.00318654, 3.24758909, 3.642827549, 4.275379011, 5.210036993, 6.558445945, 8.799623458, 12.78369364, 19.96527211, 30.3974651, 44.1302736, 67.71411312, 105.5365644, 124.7965921, 91.23693738, 60.33028814, 42.28142941, 31.83743354, 25.46424862, 21.35864485],
    'tg=60nm': [2.371541544, 2.390319704, 2.462610336, 2.598171395, 2.818330432, 3.164999147, 3.705499816, 4.485089374, 5.7047946, 7.794484945, 11.52359588, 17.64290835, 25.82505172, 37.52933148, 52.46498173, 58.5611938, 46.76819555, 33.33023834, 24.48672731, 19.09930612, 15.74379839]
})

# Extract wavelength values
wavelengths = data['wl(um)']

# Extract data for different thickness values
tg_30nm = data['tg=30nm']
tg_40nm = data['tg=40nm']
tg_50nm = data['tg=50nm']
tg_60nm = data['tg=60nm']

# Create smooth lines using interpolation
wavelengths_new = np.linspace(wavelengths.min(), wavelengths.max(), 300)

tg_30nm_smooth = make_interp_spline(wavelengths, tg_30nm)(wavelengths_new)
tg_40nm_smooth = make_interp_spline(wavelengths, tg_40nm)(wavelengths_new)
tg_50nm_smooth = make_interp_spline(wavelengths, tg_50nm)(wavelengths_new)
tg_60nm_smooth = make_interp_spline(wavelengths, tg_60nm)(wavelengths_new)


plt.figure(figsize=(8, 6))

# Plot the data with smoother lines and different colors
plt.plot(wavelengths_new, tg_30nm_smooth, color='b', label='tg=30nm')
plt.plot(wavelengths_new, tg_40nm_smooth, color='g', label='tg=40nm')
plt.plot(wavelengths_new, tg_50nm_smooth, color='r', label='tg=50nm')
plt.plot(wavelengths_new, tg_60nm_smooth, color='c', label='tg=60nm')

# Add labels and legend
plt.xlabel('Wavelength (µm)',fontsize=15)
plt.ylabel('Confinement Loss (dB/cm)',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
#plt.title('Confinement Loss vs Wavelength for Different Thicknesses')
plt.legend(fontsize=15)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# Create the DataFrame from the provided data
data = pd.DataFrame({
    'wl(um)': [0.6, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8],
    'tg=0.03um': [60.21258761, 65.11655731, 76.87442256, 76.71796494, 10.17320222, -193.9150051, -607.0434613, -374.844792, -261.1524096, -195.0976173, -153.177903, -124.8268, -104.6696195, -89.75695718, -78.36776639, -69.4435898, -62.30344034, -56.49196162, -51.69438658, -47.68683037, -44.30599164],
    'tg=0.04um': [39.28365372, 45.66484764, 53.18719858, 62.03812803, 68.90407705, 71.40716892, 74.37371475, 79.41946976, 68.67572268, 9.807895604, -162.6165602, -643.1872341, -575.57178, -383.315434, -272.9799153, -206.1022979, -162.8190691, -133.1701102, -111.8991117, -96.0620555, -83.90789844],
    'tg=0.05um': [22.27876883, 27.98211534, 34.86461144, 42.46554156, 49.91694658, 58.43902739, 67.46875956, 73.51412877, 76.37018761, 77.00493493, 68.60653971, 33.16980712, -61.0445878, -264.6774491, -476.8626813, -428.0932099, -315.7136816, -233.6578376, -179.2018229, -142.3467259, -116.4444332],
    'tg=0.06um': [12.10193145, 15.93128454, 20.90234753, 27.30449788, 35.19306985, 43.81641988, 53.11934889, 63.2270615, 71.25561299, 75.21203861, 74.58225967, 61.99801012, 22.60172929, -65.49995363, -219.0405911, -355.9675749, -338.802334, -259.6638578, -193.2637593, -146.9505588, -115.1270554]
})

# Extract wavelength values
wavelengths = data['wl(um)']

# Extract data for different thickness values
tg_0_03um = data['tg=0.03um']
tg_0_04um = data['tg=0.04um']
tg_0_05um = data['tg=0.05um']
tg_0_06um = data['tg=0.06um']

# Create smooth lines using interpolation
wavelengths_new = np.linspace(wavelengths.min(), wavelengths.max(), 300)

tg_0_03um_smooth = make_interp_spline(wavelengths, tg_0_03um)(wavelengths_new)
tg_0_04um_smooth = make_interp_spline(wavelengths, tg_0_04um)(wavelengths_new)
tg_0_05um_smooth = make_interp_spline(wavelengths, tg_0_05um)(wavelengths_new)
tg_0_06um_smooth = make_interp_spline(wavelengths, tg_0_06um)(wavelengths_new)

plt.figure(figsize=(8, 6))

# Plot the data with smoother lines and different colors
plt.plot(wavelengths_new, tg_0_03um_smooth, color='b', label='tg=30nm')
plt.plot(wavelengths_new, tg_0_04um_smooth, color='g', label='tg=40nm')
plt.plot(wavelengths_new, tg_0_05um_smooth, color='r', label='tg=50nm')
plt.plot(wavelengths_new, tg_0_06um_smooth, color='c', label='tg=60nm')


# Add labels and legend
plt.xlabel('Wavelength (µm)',fontsize=15)
plt.ylabel('Amplitude Sensitivity (RIU$^{-1}$)',fontsize=15)
#plt.title('Confinement Loss vs Wavelength for Different Thicknesses')
plt.legend(fontsize=14)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# Show the plot
plt.show()

# %%
#d1 variation////////////////

import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline


path = 'wl_CL_AS_d1d2_variation_graph.xlsx'
data= pd.read_excel(path, sheet_name='na=1.36_1.37,p=2,tg=40,d2=1')
# Data
wl = data['wl']
d1_1 = data['d1=0.6,na=1.36']
d1_2 = data['d1=0.8,na=1.36']
d1_3 = data['d1=1,na=1.36']
d1_4 = data['d1=1.2,na=1.36']


# Smoothing function
def smooth(x, y):
    x_smooth = np.linspace(min(x), max(x), 300)
    y_smooth = make_interp_spline(x, y)(x_smooth)
    return x_smooth, y_smooth

# Specified colors
colors = ['b', 'g', 'r', 'c']

# Plotting
plt.figure(figsize=(8, 6))

# Smoothed plots
for i, (data, label, color) in enumerate(zip([d1_1,d1_2,d1_3,d1_4],
                                             ['d1=0.6 um, d2=1 um', 
                                              'd1=1.2 um, d2=1 um',
                                              'd1=1.4 um, d2=1 um', 
                                              'd1=1.6 um, d2=1 um'], colors)):
    x_smooth, y_smooth = smooth(wl, data)
    plt.plot(x_smooth, y_smooth, label=label, color=color, linewidth=2)

plt.ylabel("Confinement Loss (dB/cm)", fontsize='15')
plt.xlabel("Wavelength (μm)", fontsize='15')
plt.legend(frameon=False, fontsize='15')  # Transparent legend
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(False)  # Remove grid lines completely
#plt.title("Amplitude Sensitivity vs Wavelength")
plt.show()

# %%
#d2 variation////////////////

import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline


path = 'wl_CL_AS_d1d2_variation_graph.xlsx'
data= pd.read_excel(path, sheet_name='na=1.36_1.37,p=2,tg=40,d1=1.2')
# Data
wl = data['wl']
d1_1 = data['d2=0.6,na=1.36']
d1_2 = data['d2=0.8,na=1.36']
d1_3 = data['d2=1,na=1.36']
d1_4 = data['d2=1.2,na=1.36']


# Smoothing function
def smooth(x, y):
    x_smooth = np.linspace(min(x), max(x), 300)
    y_smooth = make_interp_spline(x, y)(x_smooth)
    return x_smooth, y_smooth

# Specified colors
colors = ['b', 'g', 'r', 'c']

# Plotting
plt.figure(figsize=(8, 6))

# Smoothed plots
for i, (data, label, color) in enumerate(zip([d1_1,d1_2,d1_3,d1_4],
                                             ['d1=1.2 um, d2=0.6 um', 
                                              'd1=1.2 um, d2=0.8 um',
                                              'd1=1.2 um, d2=1 um', 
                                              'd1=1.2 um, d2=1.2 um'], colors)):
    x_smooth, y_smooth = smooth(wl, data)
    plt.plot(x_smooth, y_smooth, label=label, color=color, linewidth=2)

plt.ylabel("Confinement Loss (dB/cm)",fontsize='15')
plt.xlabel("Wavelength (μm)",fontsize='15')
plt.legend(frameon=False, fontsize='15')  # Transparent legend
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(False)  # Remove grid lines completely
#plt.title("Amplitude Sensitivity vs Wavelength")
plt.show()

# %%
#d2 variation////////////////

import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline


path = 'wl_CL_AS_d1d2_variation_graph.xlsx'
data= pd.read_excel(path, sheet_name='wl_vs_AS_with_d1d2_variation')
# Data
wl = data['wl']
d1_1 = data['d1=0.6,d2=1']
#d1_2 = data['d1=1.6,d2=0.8']
#d1_3 = data['d1=1.4,d2=0.8']
#d1_4 = data['d1=1.2,d2=0.8']
#d1_5 = data['d1=1.2,d2=0.6']
d1_6 = data['d1=0.8,d2=1']
d1_7 = data['d1=1,d2=1']
d1_8 = data['d1=1.2,d2=1']

#d1_9 = data['d1=1.2,d2=1.2']


# Smoothing function
def smooth(x, y):
    x_smooth = np.linspace(min(x), max(x), 300)
    y_smooth = make_interp_spline(x, y)(x_smooth)
    return x_smooth, y_smooth

# Specified colors
colors = ['b', 'g', 'r', 'c', 'm', 'y','b', 'g', 'r']

# Plotting
plt.figure(figsize=(8, 6))

# Smoothed plots
for i, (data, label, color) in enumerate(zip([d1_1,d1_6,d1_7,d1_8],
                                             ['d1=0.6 um, d2=1 um', 
                                              #'d1=1.6,d2=0.8',
                                              #'d1=1.4,d2=0.8', 
                                              #'d1=1.2,d2=0.8',
                                              #'d1=1.2,d2=0.6', 
                                              'd1=0.8 um, d2=1 um',
                                              'd1=1 um, d2=1 um',
                                              'd1=1.2 um, d2=1 um',
                                              #'d1=1.2,d2=1.2'
                                             ], colors)):
    x_smooth, y_smooth = smooth(wl, data)
    plt.plot(x_smooth, y_smooth, label=label, color=color, linewidth=2)

plt.ylabel("Amplitude Sensitivity (RIU$^{-1}$)",fontsize='15')
plt.xlabel("Wavelength (μm)",fontsize='15')
plt.legend(frameon=False,fontsize='15')  # Transparent legend
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(False)  # Remove grid lines completely
#plt.title("Amplitude Sensitivity vs Wavelength")
plt.show()

# %%
#d2 variation////////////////

import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline


path = 'wl_CL_AS_d1d2_variation_graph.xlsx'
data= pd.read_excel(path, sheet_name='wl_vs_AS_with_d1d2_variation')
# Data
wl = data['wl']
#d1_1 = data['d1=0.6,d2=1']
#d1_2 = data['d1=1.6,d2=0.8']
#d1_3 = data['d1=1.4,d2=0.8']
d1_4 = data['d1=1.2,d2=0.6']
d1_5 = data['d1=1.2,d2=0.8']
d1_6 = data['d1=1.2,d2=1']
#d1_7 = data['d1=0.8,d2=1']
#d1_8 = data['d1=1,d2=1']
d1_9 = data['d1=1.2,d2=1.2']


# Smoothing function
def smooth(x, y):
    x_smooth = np.linspace(min(x), max(x), 300)
    y_smooth = make_interp_spline(x, y)(x_smooth)
    return x_smooth, y_smooth

# Specified colors
colors = ['b', 'g', 'r', 'c', 'm', 'y','b', 'g', 'r']

# Plotting
plt.figure(figsize=(8, 6))

# Smoothed plots
for i, (data, label, color) in enumerate(zip([d1_4,d1_5,d1_6,d1_9],
                                             [#'d1=0.6,d2=1', 
                                              #'d1=1.6,d2=0.8',
                                              #'d1=1.4,d2=0.8', 
                                              'd1=1.2 um, d2=0.6 um',
                                              'd1=1.2 um, d2=0.8 um',
                                              'd1=1.2 um, d2=1 um',
                                              #'d1=0.8,d2=1',
                                              #'d1=1,d2=1',
                                              'd1=1.2 um, d2=1.2 um'
                                             ], colors)):
    x_smooth, y_smooth = smooth(wl, data)
    plt.plot(x_smooth, y_smooth, label=label, color=color, linewidth=2)

plt.ylabel("Amplitude Sensitivity (RIU$^{-1}$)",fontsize='15')
plt.xlabel("Wavelength (μm)",fontsize='15')
plt.legend(frameon=False,fontsize='15')  # Transparent legend
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(False)  # Remove grid lines completely
#plt.title("Amplitude Sensitivity vs Wavelength")
plt.show()

# %%
#p variation////////////////

import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline


path = 'wl_CL_AS_pitch_variation_graph.xlsx'
data= pd.read_excel(path, sheet_name='d1=0.6,d2=1,tg=40,na=1.37')
# Data
wl = data['wl']
d1_1 = data['p=2']
d1_2 = data['p=2.5']
d1_3 = data['p=3']

# Smoothing function
def smooth(x, y):
    x_smooth = np.linspace(min(x), max(x), 300)
    y_smooth = make_interp_spline(x, y)(x_smooth)
    return x_smooth, y_smooth

# Specified colors
colors = ['b', 'g', 'r']

# Plotting
plt.figure(figsize=(8, 6))

# Smoothed plots
for i, (data, label, color) in enumerate(zip([d1_1,d1_2,d1_3],
                                             ['pitch=2 um',
                                              'pitch=2.5 um',
                                              'pitch=3 um'
                                             ], colors)):
    x_smooth, y_smooth = smooth(wl, data)
    plt.plot(x_smooth, y_smooth, label=label, color=color, linewidth=2)

plt.ylabel("Confinement Loss (dB/cm)",fontsize=15)
plt.xlabel("Wavelength (μm)",fontsize=15)
plt.legend(frameon=False,fontsize=15)  # Transparent legend
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(False)  # Remove grid lines completely
#plt.title("Amplitude Sensitivity vs Wavelength")
plt.show()

# %%
#p variation///////wl vs AS/////////

import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline


path = 'wl_CL_AS_pitch_variation_graph.xlsx'
data= pd.read_excel(path, sheet_name='d1=0.6,d2=1,tg=40,1.36-1.37,AS')
# Data
wl = data['wl']
d1_1 = data['p=2']
d1_2 = data['p=2.5']
d1_3 = data['p=3']

# Smoothing function
def smooth(x, y):
    x_smooth = np.linspace(min(x), max(x), 300)
    y_smooth = make_interp_spline(x, y)(x_smooth)
    return x_smooth, y_smooth

# Specified colors
colors = ['b', 'g', 'r']

# Plotting
plt.figure(figsize=(8, 6))

# Smoothed plots
for i, (data, label, color) in enumerate(zip([d1_1,d1_2,d1_3],
                                             ['pitch=2 um',
                                              'pitch=2.5 um',
                                              'pitch=3 um'
                                             ], colors)):
    x_smooth, y_smooth = smooth(wl, data)
    plt.plot(x_smooth, y_smooth, label=label, color=color, linewidth=2)

plt.ylabel("Amplitude Sensitivity (RIU$^{-1}$)",fontsize=15)
plt.xlabel("Wavelength (μm)",fontsize=15)
plt.legend(frameon=False,fontsize=15)  # Transparent legend
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(False)  # Remove grid lines completely
#plt.title("Amplitude Sensitivity vs Wavelength")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

df= pd.read_excel('phaseMacthing_graph.xlsx')

# %%
df.isnull().sum().sum()
# Out:
# 7

# %%
# Drop rows with NaN or infinite values in any column
df = df.replace([np.inf, -np.inf], np.nan).dropna()

# Create a function to smooth the data
def smooth(x, y, num_points=300):
    x_new = np.linspace(x.min(), x.max(), num_points)
    spl = make_interp_spline(x, y, k=3)  # B-spline of order 3
    y_new = spl(x_new)
    return x_new, y_new

# Create the figure and axis
fig, ax1 = plt.subplots(figsize=(8, 6))  # Increased figure size

# Set labels and colors for the primary y-axis
ax1.set_xlabel('Wavelength (µm)', fontsize=14, color='black')
ax1.set_ylabel('Confinement loss (dB/cm)', fontsize=14, color='black')
x_smooth, y_smooth = smooth(df['wl'], df['confinement loss'])
ax1.plot(x_smooth, y_smooth, color='blue', label='Confinement loss')
ax1.tick_params(axis='y', labelcolor='black', labelsize=12)
ax1.tick_params(axis='x', labelcolor='black', labelsize=12)

# Create a secondary y-axis
ax2 = ax1.twinx()

# Set labels and colors for the secondary y-axis
ax2.set_ylabel('Effective Refractive Index', fontsize=14, color='black')
x_smooth_core, y_smooth_core = smooth(df['wl'], df['neff y core real'])
x_smooth_spp, y_smooth_spp = smooth(df['wl'], df['neff spp real'])
ax2.plot(x_smooth_core, y_smooth_core, color='red', label='neff_y_core_(real)')
ax2.plot(x_smooth_spp, y_smooth_spp, color='green', label='neff_y_spp_(real)')
ax2.tick_params(axis='y', labelcolor='black', labelsize=12)

# Remove grid lines
ax1.grid(False)
ax2.grid(False)

# Combine the legends into one
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="upper right", fontsize=12, bbox_to_anchor=(0.99, 0.99))

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

file = 'linearCorrelation_graph.xlsx'
data = pd.read_excel(file)
# Assuming the Excel file has columns named 'Analyte' and 'Wavelength'
na_values = data['Analyte'].values.reshape((-1, 1))  # Analyte column
resonance_wavelengths = data['Peak Wavelength'].values  # Resonance Wavelength column

# Polynomial Regression (Degree 2)
poly_model = PolynomialFeatures(degree=2)
x_poly = poly_model.fit_transform(na_values)

poly_reg = LinearRegression()
poly_reg.fit(x_poly, resonance_wavelengths)
y_pred_poly = poly_reg.predict(x_poly)
r2_poly = r2_score(resonance_wavelengths, y_pred_poly)

# Extract polynomial coefficients
coeffs = poly_reg.coef_
intercept = poly_reg.intercept_

# Format the equation for display inside the graph
equation_text = f"$R^2 = {r2_poly:.2f}$"
equation_line = f"$y = {coeffs[2]:.2f}x^2 {coeffs[1]:.2f}x {'+' if intercept > 0 else '-'} {(intercept):.2f}$"

# Plotting Polynomial Regression Results
plt.figure(figsize=(6, 4))
plt.scatter(na_values, resonance_wavelengths, color="blue", label="Data Points")
plt.plot(na_values, y_pred_poly, color="orange", label="Polynomial Regression")


# Adjust the text positions dynamically to keep them **inside** the graph
x_text_pos = min(na_values) + 0.00
y_text_pos = min(resonance_wavelengths) + (max(resonance_wavelengths) - min(resonance_wavelengths)) * 0.2

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.text(x_text_pos, y_text_pos + 0.08, equation_text, fontsize=13, color='black', ha='left')
plt.text(x_text_pos, y_text_pos + 0.05, equation_line, fontsize=13, color='black', ha='left')

# Labels and Titles
plt.xlabel("Analyte Refractive Index (na)", fontsize=12)
plt.ylabel("Resonance Wavelength (µm)", fontsize=12)
#plt.title("Polynomial Regression for Resonance Wavelength")
plt.legend(fontsize='12')
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
